# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.metrics import accuracy_score, mean_squared_error
from statistics import mean
import mlflow

# %%
penguins = pd.read_csv("https://github.com/allisonhorst/palmerpenguins/raw/5b5891f01b52ae26ad8cb9755ec93672f49328a8/data/penguins_size.csv")
penguins.dropna(inplace=True)

attributes = penguins.iloc[:,2:6]
scaler = StandardScaler()
num = scaler.fit_transform(attributes)
data_n = pd.DataFrame(num, columns=['culmen_length_mm','culmen_depth_mm','flipper_length_mm','body_mass_g'])

species = penguins.iloc[:, 0]
labelencoder = LabelEncoder()
cat = labelencoder.fit_transform(species)
enc_species = pd.DataFrame(cat, columns=['species_short'])

enc_species = pd.get_dummies(species)


#Tensor Of all the numerical values, lenghth etc. 
X_tensor = torch.tensor(data_n.astype(np.float32).values)

#Tensor of the encoded categorical variable
y_tensor = torch.tensor(enc_species.astype(np.float32).values)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species_short      334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
penguins['species_short'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)
# t=2023-04-29T18:50:03+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=565898f20a5d clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T18:50:03+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="session closed"
# t=2023-04-29T19:25:43+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49202->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2023-04-29T19:41:22+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49428->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2023-04-29T19:52:52+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=2d4cc25359fb clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T20:07:57+0200 lvl=eror msg="failed to reconnect session" obj=csess id=692f90eca2ac err="context deadline exceeded"
# t=2023-04-29T20:08:01+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=e632b4f31eb2 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T20:40:54+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=56da18eda97c clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T20:40:54+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="session closed"
# t=2023-04-29T20:57:55+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49590->[2600:1f16:d83:1202::6e74:2]:443: read: connection reset by peer"
# t=2023-04-29T21:14:48+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=eb390d8f3501 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T21:14:54+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49626->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2023-04-29T21:31:59+0200 lvl=eror msg="failed to reconnect session" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49666->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2023-04-29T21:50:05+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49684->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2023-04-29T22:00:00+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=21c311520d00 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T22:17:57+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49724->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2023-04-29T22:18:02+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=4aad0af73752 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T22:34:15+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49767->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2023-04-29T22:50:20+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=bb121ba47124 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T23:06:05+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49808->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2023-04-29T23:06:10+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=2e54cd5ae7ff clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T23:22:04+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49878->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2023-04-29T23:38:05+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=9b536c18891d clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-29T23:54:43+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49901->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2023-04-29T23:54:47+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=3dd5c78c92e5 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T00:12:42+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:49942->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2023-04-30T00:23:01+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=06e341e6951d clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T00:38:47+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50003->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2023-04-30T00:38:51+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=20c2ea5e7ec8 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T00:56:28+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50034->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2023-04-30T01:14:14+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=d4fb12289320 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T01:32:00+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=c7a7979334b0 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T01:47:53+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp 192.168.0.101:50077->3.134.73.173:443: read: operation timed out"
# t=2023-04-30T02:05:56+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=c9ee31987d05 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T02:06:00+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50187->[2600:1f16:d83:1201::6e74:1]:443: read: connection reset by peer"
# t=2023-04-30T02:38:52+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50242->[2600:1f16:d83:1200::6e74:0]:443: read: connection reset by peer"
# t=2023-04-30T02:38:57+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=d37373eec79c clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T02:55:18+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50299->[2600:1f16:d83:1200::6e74:3]:443: read: connection reset by peer"
# t=2023-04-30T03:06:44+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=3e682a156c66 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T03:22:34+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50336->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2023-04-30T03:22:38+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=b68f2ef4c830 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-04-30T03:39:34+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:21cb:868f:db18:2198]:50380->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2023-04-30T03:56:09+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id
0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="session closed"
# t=2023-05-01T21:31:36+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:fdc9:5c72:272e:d99]:60318->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2023-05-01T21:31:51+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=97b902bcfbd6 clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-05-01T22:52:46+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:fdc9:5c72:272e:d99]:60525->[2600:1f16:d83:1201::6e74:4]:443: read: connection reset by peer"
# t=2023-05-01T23:07:43+0200 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=692f90eca2ac err="read tcp [2a09:5e40:3054:5a0:fdc9:5c72:272e:d99]:61190->[2600:1f16:d83:1202::6e74:5]:443: read: connection reset by peer"
# t=2023-05-01T23:07:47+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=c4f4206384be clientid=b2cef244e4351a9c02b06439ad3f1d01
# t=2023-05-01T23:07:57+0200 lvl=eror msg="heartbeat timeout, terminating session" obj=csess id=e357f214d747 clientid=b2cef244e4351a9c02b06439ad3f1d01

# %%
mlflow.set_experiment("Penguins ANN")
experiment_id = mlflow.get_experiment_by_name('Penguins ANN').experiment_id
# Out:
# 2023/04/29 17:35:37 INFO mlflow.tracking.fluent: Experiment with name 'Penguins ANN' does not exist. Creating a new experiment.

# %%
with mlflow.start_run(run_name="run with artifact", nested=True, experiment_id=experiment_id):
  # Your machine learning code here
  # Initializing Hyperparameters
  epochs = 50
  learning_rate = 0.001
  loss_set = {}
  # 1. Creating a FeedForwardNetwork
  model_net4 = torch.nn.Sequential(
                            # Input layer
                            torch.nn.Linear(4,8),
                            torch.nn.ReLU(),
                            # 1. Hidden layer
                            torch.nn.Linear(8,16),
                            torch.nn.ReLU(),
                            # 2. Hidden layer
                            torch.nn.Linear(16,32),
                            torch.nn.ReLU(),
                            # 3. Hidden layer
                            torch.nn.Linear(32,64),
                            torch.nn.ReLU(),
                            # Output layer
                            torch.nn.Linear(64,3),
                            torch.nn.Softmax()  # We have a multiclass single-label classification problem, since a penguin can only be from one species
                          );
  loss_cel = torch.nn.CrossEntropyLoss()
  optimizer = torch.optim.RMSprop(model_net4.parameters(), lr=learning_rate)

  # Loop over the number of epochs
  for i in tqdm_notebook(range(epochs), total=epochs, unit="epoch"):
    lost_set_epoch = {}
    j = 0
    for x, y_t in zip(X_tensor, y_tensor):
        output = model_net4.forward(x.float())
        # 2. FeedForward Evaluation
        loss = loss_cel(output, y_t.float())
        optimizer.zero_grad();

        # 3. Backward / Gradient Calculation
        loss.backward()
        # 4. Back Propagation
        optimizer.step()
        # Store the loss for each sample of data
        lost_set_epoch[j] = loss
        j = j + 1
    
    # Store the loss for each epoch
    loss_set[i] = torch.mean(torch.stack(list(lost_set_epoch.values()))).detach().numpy()

    # Display the loss after every 10 epochs
    if (i % 10)==0:
      print (f"Loss: {loss_set[i]}")

  mlflow.log_param("Learning rate", learning_rate)
  mlflow.log_param("Num. of epochs", epochs)

  from pandas.core.groupby.groupby import OutputFrameOrSeries
  with torch.no_grad():
    n_correct = 0
    n_samples = len(y_tensor)

    outputs = model_net4.forward(X_tensor)
    for idx, output in enumerate(outputs):
      pred = np.argmax(output).item()
      true_val = np.argmax(y_tensor[idx]).item()
      
      if pred == true_val:
        n_correct += 1

    acc = 100 * (n_correct / n_samples)

  mlflow.log_metric("accuracy", acc)
  params_path = "model.pt"
  #/Users/yasminesarraj/Documents/GitHub/MLOPS-assignments/Assignment_4
  torch.save(model_net4.state_dict(), params_path)
  mlflow.log_artifact(params_path)
  
  # End the current run
  mlflow.end_run()
# Out:
# /var/folders/ss/lhx9lhjx3wn1dkd8thzyx0w40000gn/T/ipykernel_37385/2823208323.py:29: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(epochs), total=epochs, unit="epoch"):
#   0%|          | 0/50 [00:00<?, ?epoch/s]
# /Users/yasminesarraj/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Loss: 0.7510645389556885
# Loss: 0.5580784678459167
# Loss: 0.5578799843788147
# Loss: 0.5574740767478943
# Loss: 0.560384213924408

# %%
# run tracking UI in the background
get_ipython().system_raw("mlflow ui --port 5002 &")
## Step 3 - Installing pyngrok for remote tunnel access using ngrock.com

from pyngrok import ngrok
from getpass import getpass
# Terminate open tunnels if any exist
ngrok.kill()
## Step 4 - Login on ngrok.com and get your authtoken from https://dashboard.ngrok.com/auth
# Enter your auth token when the code is running
NGROK_AUTH_TOKEN = getpass('Enter the ngrok authtoken: ')
ngrok.set_auth_token(NGROK_AUTH_TOKEN)
ngrok_tunnel = ngrok.connect(addr="5002", proto="http", bind_tls=True)
print("MLflow Tracking UI:", ngrok_tunnel.public_url)
# Out:
# [2023-04-29 17:36:12 +0200] [37589] [INFO] Starting gunicorn 20.1.0
# [2023-04-29 17:36:12 +0200] [37589] [ERROR] Connection in use: ('127.0.0.1', 5002)
# [2023-04-29 17:36:12 +0200] [37589] [ERROR] Retrying in 1 second.
# t=2023-04-29T17:36:13+0200 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path="/Users/yasminesarraj/Library/Application Support/ngrok/ngrok.yml" legacy_path=/Users/yasminesarraj/.ngrok2/ngrok.yml
# [2023-04-29 17:36:13 +0200] [37589] [ERROR] Connection in use: ('127.0.0.1', 5002)
# [2023-04-29 17:36:13 +0200] [37589] [ERROR] Retrying in 1 second.
# MLflow Tracking UI: https://ee05-2a09-5e40-3054-5a0-21cb-868f-db18-2198.ngrok-free.app
# [2023-04-29 17:36:14 +0200] [37589] [ERROR] Connection in use: ('127.0.0.1', 5002)
# [2023-04-29 17:36:14 +0200] [37589] [ERROR] Retrying in 1 second.
# [2023-04-29 17:36:15 +0200] [37589] [ERROR] Connection in use: ('127.0.0.1', 5002)
# [2023-04-29 17:36:15 +0200] [37589] [ERROR] Retrying in 1 second.
# [2023-04-29 17:36:16 +0200] [37589] [ERROR] Connection in use: ('127.0.0.1', 5002)
# [2023-04-29 17:36:16 +0200] [37589] [ERROR] Retrying in 1 second.
# [2023-04-29 17:36:17 +0200] [37589] [ERROR] Can't connect to ('127.0.0.1', 5002)
# Running the mlflow server failed. Please see the logs above for details.
